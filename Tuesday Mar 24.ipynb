# %%
from science import *

# %%
x=linspace(0,20,100)
y=0.1*x+3+randn(len(x))
plot(x,y,'o')

# %%
def constant(x,a):
    return a

# %%
model=MCMCModel(x,y,constant,
                a=Uniform(-10,10))
model.run_mcmc(500)
model.plot_chains()
# Out:
# Running MCMC...
# Done.
# 1.11 s

# %%
model.plot_distributions()
