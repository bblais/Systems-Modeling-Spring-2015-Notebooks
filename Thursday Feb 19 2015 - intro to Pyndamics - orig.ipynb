# %%
from pyndamics import *
import pandas  # for data stuff

# %%
sim=Simulation()
sim.add("y'=constant*y",0.01,plot=True)
sim.params(constant=.4)
sim.run(0,10)

# %%
data=pandas.read_excel('data/s009.xls',skiprows=[0,1])
data.head()
# Out:
#    day  height (cm)
# 0    0         0.00
# 1    7        17.93
# 2   14        36.36
# 3   21        67.76
# 4   28        98.10

# %%
t,y=data['day'],data['height (cm)']

# %%
sim=Simulation()
sim.add("y'=constant",0,plot=True)
sim.params(constant=1)
sim.add_data(t=t,y=y,plot=True)
sim.run(0,90)

# %%
sim.mse('y')
# Out:
# 16474.867853846154
